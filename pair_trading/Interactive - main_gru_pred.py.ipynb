# %% [markdown]
# Connected to Python 3.10.11

# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Mar 14 09:36:03 2024

@author: sebja
"""
#%%
import numpy as np
import torch
import matplotlib.pyplot as plt 
from gru_pred import gru_pred
import dill
import statsmodels.api as sm

# %%
model = gru_pred(T=100, 
                 learning_rate = 0.001,
                 seq_length=100, n_ahead=1, 
                 gru_hidden_size = 10, gru_num_layers = 10,
                 dropout_rate=0, kappa=5, sigma=0.3, dt=0.1)

# %%
model.train(num_epochs = 10_000, n_print=500)

# %%
torch.save(model.model.state_dict(), 'model.pth')

# %%
model.model.load_state_dict(torch.load('model.pth'))
model.pred()

#mod_hamilton = sm.tsa.MarkovAutoregression(
#    dta_hamilton, k_regimes=2, order=4, switching_ar=False
#)

# %% [markdown]
# Connected to base (Python 3.9.12)

# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Mar 14 09:36:03 2024

@author: sebja
"""
#%%
import numpy as np
import torch
import matplotlib.pyplot as plt 
from gru_pred import gru_pred
import dill
import statsmodels.api as sm

# %%
model = gru_pred(T=100, 
                 learning_rate = 0.001,
                 seq_length=100, n_ahead=1, 
                 gru_hidden_size = 10, gru_num_layers = 10,
                 dropout_rate=0, kappa=5, sigma=0.3, dt=0.1)

# %%
model.train(num_epochs = 10_000, n_print=500)

# %%
torch.save(model.model.state_dict(), 'model.pth')
# Out:
# Cell was canceled due to an error in a previous cell.

# %%
model.model.load_state_dict(torch.load('model.pth'))
model.pred()

#mod_hamilton = sm.tsa.MarkovAutoregression(
#    dta_hamilton, k_regimes=2, order=4, switching_ar=False
#)
# Out:
# Cell was canceled due to an error in a previous cell.

# %% [markdown]
# Connected to Python 3.10.11

# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Mar 14 09:36:03 2024

@author: sebja
"""
#%%
import numpy as np
import torch
import matplotlib.pyplot as plt 
from gru_pred import gru_pred
import dill
import statsmodels.api as sm

# %%
model = gru_pred(T=100, 
                 learning_rate = 0.001,
                 seq_length=100, n_ahead=1, 
                 gru_hidden_size = 10, gru_num_layers = 10,
                 dropout_rate=0, kappa=5, sigma=0.3, dt=0.1)

# %%
model.train(num_epochs = 10_000, n_print=500)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Epoch [1/10000], Loss: 0.6379
#   5%|▍         | 499/10000 [01:59<44:25,  3.56it/s]
# Epoch [500/10000], Loss: -0.0000
#  10%|▉         | 999/10000 [04:07<36:36,  4.10it/s]
# Epoch [1000/10000], Loss: -0.0000
#  15%|█▍        | 1499/10000 [06:00<30:49,  4.60it/s]
# Epoch [1500/10000], Loss: 0.0000
#  20%|█▉        | 1999/10000 [07:52<27:45,  4.80it/s]
# Epoch [2000/10000], Loss: -0.0000
#  25%|██▍       | 2499/10000 [09:42<29:22,  4.26it/s]
# Epoch [2500/10000], Loss: -0.0000
#  30%|██▉       | 2999/10000 [11:32<27:16,  4.28it/s]
# Epoch [3000/10000], Loss: 0.0000
#  35%|███▍      | 3499/10000 [13:23<23:54,  4.53it/s]
# Epoch [3500/10000], Loss: -0.0000
#  40%|███▉      | 3999/10000 [15:15<22:09,  4.52it/s]
# Epoch [4000/10000], Loss: -0.0000
#  45%|████▍     | 4499/10000 [17:05<20:44,  4.42it/s]
# Epoch [4500/10000], Loss: -0.0000
#  50%|████▉     | 4999/10000 [18:57<17:34,  4.74it/s]
# Epoch [5000/10000], Loss: -0.0000
#  55%|█████▍    | 5499/10000 [20:47<17:20,  4.33it/s]
# Epoch [5500/10000], Loss: -0.0000
#  60%|█████▉    | 5999/10000 [22:39<14:51,  4.49it/s]
# Epoch [6000/10000], Loss: 0.0000
#  65%|██████▍   | 6499/10000 [24:28<12:18,  4.74it/s]
# Epoch [6500/10000], Loss: -0.0000
#  70%|██████▉   | 6999/10000 [26:22<10:09,  4.92it/s]
# Epoch [7000/10000], Loss: -0.0000
#  75%|███████▍  | 7499/10000 [28:12<09:09,  4.55it/s]
# Epoch [7500/10000], Loss: 0.0000
#  80%|███████▉  | 7999/10000 [30:05<06:57,  4.79it/s]
# Epoch [8000/10000], Loss: 0.0177
#  85%|████████▍ | 8499/10000 [31:54<05:30,  4.55it/s]
# Epoch [8500/10000], Loss: -0.0000
#  90%|████████▉ | 8999/10000 [33:42<03:50,  4.34it/s]
# Epoch [9000/10000], Loss: -0.0000
#  95%|█████████▍| 9499/10000 [35:33<01:50,  4.52it/s]
# Epoch [9500/10000], Loss: -0.0000
# 100%|█████████▉| 9999/10000 [37:23<00:00,  4.40it/s]
# Epoch [10000/10000], Loss: -0.0000
# 100%|██████████| 10000/10000 [37:24<00:00,  4.46it/s]

# %%
torch.save(model.model.state_dict(), 'model.pth')

# %%
model.model.load_state_dict(torch.load('model.pth'))
model.pred()

#mod_hamilton = sm.tsa.MarkovAutoregression(
#    dta_hamilton, k_regimes=2, order=4, switching_ar=False
#)
