# %% [markdown]
# Connected to Python 3.10.11

# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Mar 14 09:36:03 2024

@author: sebja
"""
#%%
import numpy as np
import torch
import matplotlib.pyplot as plt 
from gru_pred import gru_pred
import dill

# %%
model = gru_pred(T=40, 
                 learning_rate = 0.001,
                 seq_length=20, n_ahead=1, 
                 dropout_rate=0, kappa=5, sigma=0.22, dt=0.2)

model.train(num_epochs = 10_000, n_print=500)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Epoch [1/10000], Loss: 1.0325
#   5%|▍         | 499/10000 [01:31<29:16,  5.41it/s]
# Epoch [500/10000], Loss: 1.0958
#  10%|▉         | 999/10000 [03:13<27:00,  5.55it/s]
# Epoch [1000/10000], Loss: 0.4379
#  15%|█▍        | 1499/10000 [04:48<24:50,  5.70it/s]
# Epoch [1500/10000], Loss: 0.7462
#  20%|█▉        | 1999/10000 [06:29<29:07,  4.58it/s]
# Epoch [2000/10000], Loss: 0.4893
#  25%|██▍       | 2499/10000 [08:08<21:30,  5.81it/s]
# Epoch [2500/10000], Loss: 0.5455
#  30%|██▉       | 2999/10000 [09:45<23:08,  5.04it/s]
# Epoch [3000/10000], Loss: 0.4222
#  35%|███▍      | 3499/10000 [11:27<26:32,  4.08it/s]
# Epoch [3500/10000], Loss: 0.3068
#  40%|███▉      | 3999/10000 [13:02<19:44,  5.07it/s]
# Epoch [4000/10000], Loss: 0.2755
#  45%|████▍     | 4499/10000 [14:45<19:18,  4.75it/s]
# Epoch [4500/10000], Loss: 0.7677
#  50%|████▉     | 4999/10000 [16:21<16:49,  4.95it/s]
# Epoch [5000/10000], Loss: 0.3054
#  55%|█████▍    | 5499/10000 [17:57<16:45,  4.48it/s]
# Epoch [5500/10000], Loss: 0.6951
#  60%|█████▉    | 5999/10000 [19:42<13:14,  5.03it/s]
# Epoch [6000/10000], Loss: 0.3649
#  65%|██████▍   | 6499/10000 [21:16<11:13,  5.20it/s]
# Epoch [6500/10000], Loss: 0.6285
#  70%|██████▉   | 6999/10000 [22:59<11:36,  4.31it/s]
# Epoch [7000/10000], Loss: 0.4085
#  75%|███████▍  | 7499/10000 [25:01<08:22,  4.97it/s]
# Epoch [7500/10000], Loss: 0.3359
#  80%|███████▉  | 7999/10000 [26:35<07:16,  4.59it/s]
# Epoch [8000/10000], Loss: 0.5108
#  85%|████████▍ | 8499/10000 [28:15<05:19,  4.70it/s]
# Epoch [8500/10000], Loss: 0.4891
#  90%|████████▉ | 8999/10000 [29:54<03:54,  4.27it/s]
# Epoch [9000/10000], Loss: 0.3664
#  95%|█████████▍| 9499/10000 [32:10<02:49,  2.95it/s]
# Epoch [9500/10000], Loss: 0.4321
# 100%|█████████▉| 9999/10000 [35:19<00:00,  3.09it/s]
# Epoch [10000/10000], Loss: 0.4439
# 100%|██████████| 10000/10000 [35:20<00:00,  4.71it/s]

# %% [markdown]
# No kernel connected

# %% [markdown]
# No kernel connected

# %% [markdown]
# No kernel connected

# %% [markdown]
# No kernel connected

# %% [markdown]
# No kernel connected

# %% [markdown]
# No kernel connected

# %% [markdown]
# No kernel connected

# %% [markdown]
# No kernel connected

# %% [markdown]
# No kernel connected

# %% [markdown]
# No kernel connected

# %% [markdown]
# No kernel connected

# %% [markdown]
# No kernel connected

# %% [markdown]
# No kernel connected

# %% [markdown]
# No kernel connected

# %% [markdown]
# No kernel connected

# %% [markdown]
# No kernel connected

# %% [markdown]
# No kernel connected
