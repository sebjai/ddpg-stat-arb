# %% [markdown]
# Connected to Python 3.10.11

# %%
# -*- coding: utf-8 -*-
#%%
import matplotlib.pyplot as plt
#plt.style.use('paper.mplstyle')

from MR_env import MR_env
from DDPG import DDPG
from gru_pred import gru_pred

import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

env = MR_env(S_0 = 1, kappa = 5, sigma = 0.1, theta = [0.9, 1, 1.1 ],
             dt = 0.5, T = 10.1, 
             I_max = 10, lambd = 0.05)

gru = gru_pred(T = env.T, dt = env.dt, learning_rate = 0.001,
                 seq_length = 10, n_ahead = 1, 
                 dropout_rate = 0, kappa = env.kappa, sigma = env.sigma, batch_size = 16)

ddpg = DDPG(env, gru = gru, I_max = 10,
            gamma = 0.999, 
            lr=1e-3,
            n_nodes=20, n_layers=6, 
            name="test" )

# %%
ddpg.train(n_iter=10_000, n_plot=200, mini_batch_size=32)

# %% [markdown]
# No kernel connected

# %% [markdown]
# No kernel connected

# %%
# -*- coding: utf-8 -*-
#%%
import matplotlib.pyplot as plt
#plt.style.use('paper.mplstyle')

from MR_env import MR_env
from DDPG import DDPG
from gru_pred import gru_pred

import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

env = MR_env(S_0 = 1, kappa = 5, sigma = 0.1, theta = [0.9, 1, 1.1 ],
             dt = 0.5, T = 10.1, 
             I_max = 10, lambd = 0.05)

gru = gru_pred(T = env.T, dt = env.dt, learning_rate = 0.001,
                 seq_length = 10, n_ahead = 1, 
                 dropout_rate = 0, kappa = env.kappa, sigma = env.sigma, batch_size = 16)

ddpg = DDPG(env, gru = gru, I_max = 10,
            gamma = 0.999, 
            lr=1e-3,
            n_nodes=20, n_layers=6, 
            name="test" )

# %%
#%%

ddpg.train(n_iter=10_000, n_plot=200, mini_batch_size=32)
# Out:
#   2%|▏         | 199/10000 [03:11<2:39:01,  1.03it/s]c:\Users\macri\Desktop\ddpg-stat-arb\model-prob\ddpg+gru\DDPG.py:548: UserWarning: All values for SymLogScale are below linthresh, making it effectively linear. You likely should lower the value of linthresh.
#   plt.tight_layout()
#   4%|▍         | 399/10000 [08:27<2:17:03,  1.17it/s]  c:\Users\macri\Desktop\ddpg-stat-arb\model-prob\ddpg+gru\DDPG.py:548: UserWarning: All values for SymLogScale are below linthresh, making it effectively linear. You likely should lower the value of linthresh.
#   plt.tight_layout()
#   6%|▌         | 599/10000 [13:21<2:16:45,  1.15it/s]  c:\Users\macri\Desktop\ddpg-stat-arb\model-prob\ddpg+gru\DDPG.py:548: UserWarning: All values for SymLogScale are below linthresh, making it effectively linear. You likely should lower the value of linthresh.
#   plt.tight_layout()
#   8%|▊         | 799/10000 [18:09<2:08:47,  1.19it/s] c:\Users\macri\Desktop\ddpg-stat-arb\model-prob\ddpg+gru\DDPG.py:548: UserWarning: All values for SymLogScale are below linthresh, making it effectively linear. You likely should lower the value of linthresh.
#   plt.tight_layout()
#  10%|▉         | 999/10000 [22:58<2:04:50,  1.20it/s] c:\Users\macri\Desktop\ddpg-stat-arb\model-prob\ddpg+gru\DDPG.py:548: UserWarning: All values for SymLogScale are below linthresh, making it effectively linear. You likely should lower the value of linthresh.
#   plt.tight_layout()
#  12%|█▏        | 1199/10000 [27:48<2:05:55,  1.16it/s] c:\Users\macri\Desktop\ddpg-stat-arb\model-prob\ddpg+gru\DDPG.py:548: UserWarning: All values for SymLogScale are below linthresh, making it effectively linear. You likely should lower the value of linthresh.
#   plt.tight_layout()
#  14%|█▍        | 1399/10000 [32:46<2:02:32,  1.17it/s] c:\Users\macri\Desktop\ddpg-stat-arb\model-prob\ddpg+gru\DDPG.py:548: UserWarning: All values for SymLogScale are below linthresh, making it effectively linear. You likely should lower the value of linthresh.
#   plt.tight_layout()
#  16%|█▌        | 1599/10000 [37:44<2:06:39,  1.11it/s] c:\Users\macri\Desktop\ddpg-stat-arb\model-prob\ddpg+gru\DDPG.py:548: UserWarning: All values for SymLogScale are below linthresh, making it effectively linear. You likely should lower the value of linthresh.
#   plt.tight_layout()
#  18%|█▊        | 1799/10000 [44:14<2:23:48,  1.05s/it] c:\Users\macri\Desktop\ddpg-stat-arb\model-prob\ddpg+gru\DDPG.py:548: UserWarning: All values for SymLogScale are below linthresh, making it effectively linear. You likely should lower the value of linthresh.
#   plt.tight_layout()
#  20%|█▉        | 1999/10000 [51:09<2:20:11,  1.05s/it]  c:\Users\macri\Desktop\ddpg-stat-arb\model-prob\ddpg+gru\DDPG.py:548: UserWarning: All values for SymLogScale are below linthresh, making it effectively linear. You likely should lower the value of linthresh.
#   plt.tight_layout()
#  22%|██▏       | 2199/10000 [57:31<2:11:24,  1.01s/it]  c:\Users\macri\Desktop\ddpg-stat-arb\model-prob\ddpg+gru\DDPG.py:548: UserWarning: All values for SymLogScale are below linthresh, making it effectively linear. You likely should lower the value of linthresh.
#   plt.tight_layout()
#  24%|██▍       | 2399/10000 [1:02:49<1:52:57,  1.12it/s]c:\Users\macri\Desktop\ddpg-stat-arb\model-prob\ddpg+gru\DDPG.py:548: UserWarning: All values for SymLogScale are below linthresh, making it effectively linear. You likely should lower the value of linthresh.
#   plt.tight_layout()
#  26%|██▌       | 2599/10000 [1:08:00<1:52:01,  1.10it/s] c:\Users\macri\Desktop\ddpg-stat-arb\model-prob\ddpg+gru\DDPG.py:548: UserWarning: All values for SymLogScale are below linthresh, making it effectively linear. You likely should lower the value of linthresh.
#   plt.tight_layout()
#  28%|██▊       | 2799/10000 [1:13:08<1:51:23,  1.08it/s] c:\Users\macri\Desktop\ddpg-stat-arb\model-prob\ddpg+gru\DDPG.py:548: UserWarning: All values for SymLogScale are below linthresh, making it effectively linear. You likely should lower the value of linthresh.
#   plt.tight_layout()
#  30%|██▉       | 2999/10000 [1:18:16<1:44:13,  1.12it/s] c:\Users\macri\Desktop\ddpg-stat-arb\model-prob\ddpg+gru\DDPG.py:548: UserWarning: All values for SymLogScale are below linthresh, making it effectively linear. You likely should lower the value of linthresh.
#   plt.tight_layout()
#  31%|███       | 3055/10000 [1:21:17<1:58:04,  1.02s/it]
